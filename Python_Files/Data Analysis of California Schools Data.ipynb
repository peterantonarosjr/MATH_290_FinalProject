# %% [markdown]
# # Data Analysis of California Schools Data
# ## 5/12/2022

# %%
# install psycopg2 in case don't have the library.
#!pip install psycopg2

# for generating cool reports
#!pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
# importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import psycopg2
from pandas_profiling import ProfileReport

# %%
# setting up connect to PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    database="schools",
    user="postgres",
    password="6491")

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

#Executing an MYSQL function using the execute() method
cursor.execute("select version()")

#Setting auto commit false
#conn.autocommit = True

#Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
#Retrieving `frpm` data
cursor.execute('''select * from schools.public.frpm''')

#Fetching all rows from the table
frpm_raw = cursor.fetchall();

frpm = pd.DataFrame(list(frpm_raw), 
                  columns = ["CDSCode"  
                            ,"Academic Year" 
                            ,"County Code" 
                            ,"District Code" 
                            ,"School Code" 
                            ,"County Name" 
                            ,"District Name" 
                            ,"School Name" 
                            ,"District Type" 
                            ,"School Type" 
                            ,"Educational Option Type" 
                            ,"NSLP Provision Status" 
                            ,"Charter School (Y/N)" 
                            ,"Charter School Number" 
                            ,"Charter Funding Type" 
                            ,"IRC" 
                            ,"Low Grade" 
                            ,"High Grade" 
                            ,"Enrollment (K-12)" 
                            ,"Free Meal Count (K-12)" 
                            ,"Percent (%) Eligible Free (K-12)" 
                            ,"FRPM Count (K-12)" 
                            ,"Percent (%) Eligible FRPM (K-12)" 
                            ,"Enrollment (Ages 5-17)" 
                            ,"Free Meal Count (Ages 5-17)" 
                            ,"Percent (%) Eligible Free (Ages 5-17)" 
                            ,"FRPM Count (Ages 5-17)" 
                            ,"Percent (%) Eligible FRPM (Ages 5-17)" 
                            ,"2013-14 CALPADS Fall 1 Certification Status"
                            ])

# snapshot
frpm
# Out:
#               CDSCode Academic Year County Code  District Code School Code  \
# 0      09618530000001     2014-2015          09        61853.0     0000001
# 1      10623720000000     2014-2015          10        62372.0     0000000
# 2      04614240000001     2014-2015          04        61424.0     0000001
# 3      10621660000001     2014-2015          10        62166.0     0000001
# 4      19642611930288     2014-2015          19        64261.0     1930288
# ...               ...           ...         ...            ...         ...
# 10390  58727516118806     2014-2015          58        72751.0     6118806
# 10391  58727690123570     2014-2015          58        72769.0     0123570
# 10392  58727695838305     2014-2015          58        72769.0     5838305
# 10393            None                                      NaN
# 10394            None                                      NaN
#
#        County Name          District Name                      School Name  \
# 0        El Dorado   El Dorado Union High  Nonpublic, Nonsectarian Schools
# 1           Fresno  Pine Ridge Elementary                  District Office
# 2            Butte          Chico Unified  Nonpublic, Nonsectarian Schools
# 3           Fresno         Fresno Unified  Nonpublic, Nonsectarian Schools
# 4      Los Angeles        Arcadia Unified                     Arcadia High
# ...            ...                    ...                              ...
# 10390         Yuba              Wheatland        Wheatland Charter Academy
# 10391         Yuba   Wheatland Union High     Wheatland Community Day High
# 10392         Yuba   Wheatland Union High             Wheatland Union High
# 10393
# 10394
#
#                     District Type                     School Type  ...  \
# 0            High School District                                  ...
# 1      Elementary School District                                  ...
# 2         Unified School District                                  ...
# 3         Unified School District                                  ...
# 4         Unified School District           High Schools (Public)  ...
# ...                           ...                             ...  ...
# 10390  Elementary School District           K-12 Schools (Public)  ...
# 10391        High School District  District Community Day Schools  ...
# 10392        High School District           High Schools (Public)  ...
# 10393                                                              ...
# 10394                                                              ...
#
#       Free Meal Count (K-12) Percent (%) Eligible Free (K-12)  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        1.0                         0.333333
# 3                        NaN                              NaN
# 4                      430.0                         0.124493
# ...                      ...                              ...
# 10390                   19.0                         0.215909
# 10391                    NaN                              NaN
# 10392                  164.0                         0.224044
# 10393                    NaN                              NaN
# 10394              3119368.0                         0.500184
#
#        FRPM Count (K-12) Percent (%) Eligible FRPM (K-12)  \
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    1.0                         0.333333
# 3                    NaN                              NaN
# 4                  654.0                         0.189346
# ...                  ...                              ...
# 10390               40.0                         0.454545
# 10391                NaN                              NaN
# 10392              227.0                         0.310109
# 10393                NaN                              NaN
# 10394          3655624.0                         0.586172
#
#       Enrollment (Ages 5-17)  Free Meal Count (Ages 5-17)  \
# 0                        4.0                          NaN
# 1                        7.0                          NaN
# 2                        3.0                          1.0
# 3                       10.0                          NaN
# 4                     3387.0                        421.0
# ...                      ...                          ...
# 10390                   88.0                         19.0
# 10391                    3.0                          NaN
# 10392                  711.0                        158.0
# 10393                    NaN                          NaN
# 10394              6070831.0                    3032898.0
#
#       Percent (%) Eligible Free (Ages 5-17) FRPM Count (Ages 5-17)  \
# 0                                       NaN                    NaN
# 1                                       NaN                    NaN
# 2                                  0.333333                    1.0
# 3                                       NaN                    NaN
# 4                                  0.124299                  644.0
# ...                                     ...                    ...
# 10390                              0.215909                   40.0
# 10391                                   NaN                    NaN
# 10392                              0.222222                  220.0
# 10393                                   NaN                    NaN
# 10394                              0.499585              3557989.0
#
#        Percent (%) Eligible FRPM (Ages 5-17)  \
# 0                                        NaN
# 1                                        NaN
# 2                                   0.333333
# 3                                        NaN
# 4                                   0.190139
# ...                                      ...
# 10390                               0.454545
# 10391                                    NaN
# 10392                               0.309423
# 10393                                    NaN
# 10394                               0.586079
#
#        2013-14 CALPADS Fall 1 Certification Status
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
# ...                                            ...
# 10390                                          1.0
# 10391                                          1.0
# 10392                                          1.0
# 10393                                          NaN
# 10394                                          NaN
#
# [10395 rows x 29 columns]

# %%
# filtering for high schools
frpm = frpm[(frpm['Low Grade'] == '9') & (frpm['High Grade'] == '12')]

# %%
#Retrieving `frpm` data
cursor.execute('''select * from schools.public.sat_scores''')

#Fetching all rows from the table
sat_scores_raw = cursor.fetchall();

sat_scores = pd.DataFrame(list(sat_scores_raw), 
                  columns = ["CDSCode", 
                             "rtype", 
                             "sname", 
                             "dname", 
                             "cname",
                             "enroll12", 
                             "NumTstTakr", 
                             "AvgScrRead", 
                             "AvgScrMath",
                             "AvgScrWrite", 
                             "NumGE1500", 
                             "PctGE1500"
                             ])

# snapshot
sat_scores
# Out:
#              CDSCode rtype                                    sname  \
# 0     00000000000000     X
# 1     01000000000000     C
# 2     01100170000000     D
# 3     01100170109835     S                      FAME Public Charter
# 4     01100170112607     S   Envision Academy for Arts & Technology
# ...              ...   ...                                      ...
# 2326  58727365830054     S          Lincoln (Abraham) (Alternative)
# 2327  58727365830138     S  Marysville Charter Academy for the Arts
# 2328  58727365835202     S                          Marysville High
# 2329  58727690000000     D
# 2330  58727695838305     S                     Wheatland Union High
#
#                                    dname    cname  enroll12  NumTstTakr  \
# 0                                                    496901      210706
# 1                                         Alameda     16978        8855
# 2     Alameda County Office of Education  Alameda       398          88
# 3     Alameda County Office of Education  Alameda        62          17
# 4     Alameda County Office of Education  Alameda        75          71
# ...                                  ...      ...       ...         ...
# 2326            Marysville Joint Unified     Yuba        97           0
# 2327            Marysville Joint Unified     Yuba        41          29
# 2328            Marysville Joint Unified     Yuba       197          53
# 2329                Wheatland Union High     Yuba       160          54
# 2330                Wheatland Union High     Yuba       160          54
#
#       AvgScrRead  AvgScrMath  AvgScrWrite  NumGE1500  PctGE1500
# 0          489.0       500.0        484.0    93334.0      44.30
# 1          516.0       536.0        517.0     4900.0      55.34
# 2          418.0       418.0        417.0       14.0      15.91
# 3          503.0       546.0        505.0        9.0      52.94
# 4          397.0       387.0        395.0        5.0       7.04
# ...          ...         ...          ...        ...        ...
# 2326         NaN         NaN          NaN        NaN        NaN
# 2327       501.0       494.0        484.0       16.0      55.17
# 2328       489.0       513.0        487.0       24.0      45.28
# 2329       480.0       475.0        463.0       21.0      38.89
# 2330       480.0       475.0        463.0       21.0      38.89
#
# [2331 rows x 12 columns]

# %%
# it looks like when the 'sname', 'dname' or 'cname' columns are empty
# then that row represents some aggregate average of the school, district
# or county averages.
# We only want raw scores per school.
# Lets remove rows where sname, dname or cname are missing.

# replacing empty strings with NaN
sat_scores = sat_scores.replace(r'^\s*$', np.nan, regex=True)

# filtering against na values in col subset
sat_scores = sat_scores.dropna(subset = ['sname', 'dname', 'cname'])

# reseting index
sat_scores.reset_index(inplace = True)

# drop index col
sat_scores.drop('index', axis=1, inplace=True)

# snapshot
sat_scores
# Out:
#              CDSCode rtype                                          sname  \
# 0     01100170109835     S                            FAME Public Charter
# 1     01100170112607     S         Envision Academy for Arts & Technology
# 2     01100170118489     S  Aspire California College Preparatory Academy
# 3     01611190106401     S       Alameda Science and Technology Institute
# 4     01611190119222     S                  Nea Community Learning Center
# ...              ...   ...                                            ...
# 1748  58727365830013     S                                 Lindhurst High
# 1749  58727365830054     S                Lincoln (Abraham) (Alternative)
# 1750  58727365830138     S        Marysville Charter Academy for the Arts
# 1751  58727365835202     S                                Marysville High
# 1752  58727695838305     S                           Wheatland Union High
#
#                                    dname    cname  enroll12  NumTstTakr  \
# 0     Alameda County Office of Education  Alameda        62          17
# 1     Alameda County Office of Education  Alameda        75          71
# 2     Alameda County Office of Education  Alameda        61           0
# 3                        Alameda Unified  Alameda        36          36
# 4                        Alameda Unified  Alameda        12           6
# ...                                  ...      ...       ...         ...
# 1748            Marysville Joint Unified     Yuba       221          65
# 1749            Marysville Joint Unified     Yuba        97           0
# 1750            Marysville Joint Unified     Yuba        41          29
# 1751            Marysville Joint Unified     Yuba       197          53
# 1752                Wheatland Union High     Yuba       160          54
#
#       AvgScrRead  AvgScrMath  AvgScrWrite  NumGE1500  PctGE1500
# 0          503.0       546.0        505.0        9.0      52.94
# 1          397.0       387.0        395.0        5.0       7.04
# 2            NaN         NaN          NaN        NaN        NaN
# 3          562.0       590.0        555.0       29.0      80.56
# 4            NaN         NaN          NaN        NaN        NaN
# ...          ...         ...          ...        ...        ...
# 1748       428.0       450.0        423.0       13.0      20.00
# 1749         NaN         NaN          NaN        NaN        NaN
# 1750       501.0       494.0        484.0       16.0      55.17
# 1751       489.0       513.0        487.0       24.0      45.28
# 1752       480.0       475.0        463.0       21.0      38.89
#
# [1753 rows x 12 columns]

# %%
#Retrieving `frpm` data
cursor.execute('''select * from schools.public.schools''')

#Fetching all rows from the table
schools_raw = cursor.fetchall();

schools = pd.DataFrame(list(schools_raw), 
                  columns = ["CDSCode" 
                            ,"NCESDist"
                            ,"NCESSchool"
                            ,"StatusType"
                            ,"County"
                            ,"Distrinct"
                            ,"School"
                            ,"Street"
                            ,"StreetAbr"
                            ,"City"
                            ,"Zip"
                            ,"State"
                            ,"MailStreet"
                            ,"MailStrAbr"
                            ,"MailCity"
                            ,"MailZip"
                            ,"MailState"
                            ,"Phone"
                            ,"Ext"
                            ,"Website"
                            ,"OpenDate"
                            ,"ClosedDate"
                            ,"Charter"
                            ,"CharterNum"
                            ,"FundingType"
                            ,"DOC"
                            ,"DOCType"
                            ,"SOC"
                            ,"SOCType"
                            ,"EdOpsCode"
                            ,"EdOpsName"
                            ,"EILCode"
                            ,"EILName"
                            ,"GSoffered"
                            ,"GSserved"
                            ,"Virtual"
                            ,"Magnet"
                            ,"Latitude"
                            ,"Longitude"
                            ,"AdmFName1"
                            ,"AdmLName1"
                            ,"AdmEmail1"
                            ,"AdmFName2"
                            ,"AdmLName2"
                            ,"AdmEmail2"
                            ,"AdmFName3"
                            ,"AdmLName3"
                            ,"AdmEmail3"
                            ,"LastUpdate"
                            ,"district"])

# snapshot
schools
# Out:
#              CDSCode NCESDist NCESSchool StatusType       County Distrinct  \
# 0     01100170000000  0691051                Active      Alameda      None
# 1     01100170109835  0691051      10546     Closed      Alameda      None
# 2     01100170112607  0691051      10947     Active      Alameda      None
# 3     01100170118489  0691051      12283     Closed      Alameda      None
# 4     01100170123968  0691051      12844     Active      Alameda      None
# ...              ...      ...        ...        ...          ...       ...
# 4995  19647330120360  0622710      12525     Active  Los Angeles      None
# 4996  19647330120477  0622710      12447     Active  Los Angeles      None
# 4997  19647330120527  0622710      12491     Active  Los Angeles      None
# 4998  19647330120667  0622710      12516     Closed  Los Angeles      None
# 4999  19647330120808  0622710      12482     Active  Los Angeles      None
#
#                                                School  \
# 0
# 1                                 FAME Public Charter
# 2              Envision Academy for Arts & Technology
# 3       Aspire California College Preparatory Academy
# 4             Community School for Creative Education
# ...                                               ...
# 4995  Daniel Pearl Journalism & Communications Magnet
# 4996                             Aspire Titan Academy
# 4997             Watts Learning Center Charter Middle
# 4998            Futuro College Preparatory Elementary
# 4999                 Dorothy V. Johnson Community Day
#
#                                 Street                      StreetAbr  \
# 0               313 West Winton Avenue           313 West Winton Ave.
# 1     39899 Balentine Drive, Suite 335  39899 Balentine Dr., Ste. 335
# 2                  1515 Webster Street               1515 Webster St.
# 3                2125 Jefferson Avenue            2125 Jefferson Ave.
# 4         2111 International Boulevard       2111 International Blvd.
# ...                                ...                            ...
# 4995             6649 Balboa Boulevard              6649 Balboa Blvd.
# 4996         6720 South Alameda Street         6720 South Alameda St.
# 4997       8800 South San Pedro Street       8800 South San Pedro St.
# 4998               1314 Dacatah Street               1314 Dacatah St.
# 4999        10601 South Grandee Avenue       10601 South Grandee Ave.
#
#                  City  ... AdmLName1  \
# 0             Hayward  ...    Monroe
# 1              Newark  ...
# 2             Oakland  ...    Robell
# 3            Berkeley  ...
# 4             Oakland  ...  Thompson
# ...               ...  ...       ...
# 4995         Van Nuys  ...     Smith
# 4996  Huntington Park  ...  Lafaurie
# 4997      Los Angeles  ...    Windom
# 4998      Los Angeles  ...
# 4999      Los Angeles  ...    Stiger
#
#                                               AdmEmail1 AdmFName2 AdmLName2  \
# 0                                     lkmonroe@acoe.org
# 1
# 2                             laura@envisionacademy.org
# 3
# 4     cliffordt@communityschoolforcreativeeducation.org
# ...                                                 ...       ...       ...
# 4995                             debbie.smith@lausd.net
# 4996           leilani.lafaurie@aspirepublicschools.org  Delphine   Sherman
# 4997                                 gwindom@wlccms.org
# 4998
# 4999                          kenyatta.stiger@lausd.net
#
#                                      AdmEmail2 AdmFName3 AdmLName3 AdmEmail3  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...       ...       ...       ...
# 4995
# 4996  delphine.sherman@aspirepublicschools.org
# 4997
# 4998
# 4999
#
#       LastUpdate                            district
# 0     2015-06-23  Alameda County Office of Education
# 1     2015-09-01  Alameda County Office of Education
# 2     2015-06-18  Alameda County Office of Education
# 3     2015-07-01  Alameda County Office of Education
# 4     2016-07-18  Alameda County Office of Education
# ...          ...                                 ...
# 4995  2016-03-03                 Los Angeles Unified
# 4996  2016-09-22                 Los Angeles Unified
# 4997  2016-10-07                 Los Angeles Unified
# 4998  2013-07-09                 Los Angeles Unified
# 4999  2015-06-18                 Los Angeles Unified
#
# [5000 rows x 50 columns]

# %%
# cleaning schools zip code
# there are '-####' in the column, we'll remove them
schools_zip = []

for i in range(len(schools)):
    val = schools.Zip.str.split('-')[i][0]
    if val == '':
        val = np.nan
    else:
        val = round(int(val))
    schools_zip += [val]
    
schools['Zip'] = schools_zip

# %%
# Generating Reports
"""
from pandas_profiling import ProfileReport

frpm_profile = ProfileReport(frpm)
frpm_profile.to_file("Free_Reduced_Priced_Meals_Profile.html")

schools_profile = ProfileReport(schools)
schools_profile.to_file("Schools_Profile.html")

sat_scores_profile = ProfileReport(sat_scores)
sat_scores_profile.to_file("Sat_Scores_Profile.html")
"""
# Out:
# '\nfrom pandas_profiling import ProfileReport\n\nfrpm_profile = ProfileReport(frpm)\nfrpm_profile.to_file("Free_Reduced_Priced_Meals_Profile.html")\n\nschools_profile = ProfileReport(schools)\nschools_profile.to_file("Schools_Profile.html")\n\nsat_scores_profile = ProfileReport(sat_scores)\nsat_scores_profile.to_file("Sat_Scores_Profile.html")\n'

# %% [markdown]
# ---
# ## Importing California Income Data
#
# Source: [US Census Data 2014 - California](ACSST5Y2014.S1901_metadata)
#
# I'm going to import the file here and filter for the only two columns we need for our project.

# %%
# reading csv
cali_14 = pd.read_csv("https://raw.githubusercontent.com/peterantonarosjr/MATH_290_FinalProject/main/Dataset/US%202014%20Census%20Data/ACSST5Y2014.S1901_data_with_overlays.csv")

cali_14
# Out:
#               GEO_ID                  NAME               S1901_C01_001E  \
# 0                 id  Geographic Area Name  Households!!Estimate!!Total
# 1     8600000US89010           ZCTA5 89010                          172
# 2     8600000US89019           ZCTA5 89019                          914
# 3     8600000US89060           ZCTA5 89060                         4076
# 4     8600000US89061           ZCTA5 89061                         2123
# ...              ...                   ...                          ...
# 1766  8600000US96150           ZCTA5 96150                        11388
# 1767  8600000US96155           ZCTA5 96155                            0
# 1768  8600000US96161           ZCTA5 96161                         7071
# 1769  8600000US97635           ZCTA5 97635                          151
# 1770     0400000US06            California                     12617280
#
#                           S1901_C01_001M  \
# 0     Households!!Margin of Error!!Total
# 1                                     44
# 2                                    269
# 3                                    353
# 4                                    235
# ...                                  ...
# 1766                                 493
# 1767                                  12
# 1768                                 356
# 1769                                  76
# 1770                               20413
#
#                                S1901_C01_002E  \
# 0     Households!!Estimate!!Less than $10,000
# 1                                        14.5
# 2                                         0.0
# 3                                         6.4
# 4                                         2.5
# ...                                       ...
# 1766                                      7.1
# 1767                                        -
# 1768                                      4.5
# 1769                                      0.0
# 1770                                      5.8
#
#                                       S1901_C01_002M  \
# 0     Households!!Margin of Error!!Less than $10,000
# 1                                               12.0
# 2                                                3.2
# 3                                                2.7
# 4                                                2.4
# ...                                              ...
# 1766                                             1.7
# 1767                                              **
# 1768                                             2.0
# 1769                                            17.9
# 1770                                             0.1
#
#                                 S1901_C01_003E  \
# 0     Households!!Estimate!!$10,000 to $14,999
# 1                                          0.0
# 2                                          7.5
# 3                                          8.4
# 4                                          5.7
# ...                                        ...
# 1766                                       7.2
# 1767                                         -
# 1768                                       1.7
# 1769                                       7.9
# 1770                                       5.1
#
#                                        S1901_C01_003M  \
# 0     Households!!Margin of Error!!$10,000 to $14,999
# 1                                                15.9
# 2                                                 7.7
# 3                                                 3.7
# 4                                                 3.9
# ...                                               ...
# 1766                                              1.8
# 1767                                               **
# 1768                                              1.3
# 1769                                             12.8
# 1770                                              0.1
#
#                                 S1901_C01_004E  \
# 0     Households!!Estimate!!$15,000 to $24,999
# 1                                         14.5
# 2                                         27.8
# 3                                         17.1
# 4                                          7.2
# ...                                        ...
# 1766                                       9.6
# 1767                                         -
# 1768                                       6.5
# 1769                                      18.5
# 1770                                       9.5
#
#                                        S1901_C01_004M  ...  \
# 0     Households!!Margin of Error!!$15,000 to $24,999  ...
# 1                                                10.6  ...
# 2                                                15.2  ...
# 3                                                 5.1  ...
# 4                                                 3.5  ...
# ...                                               ...  ...
# 1766                                              1.8  ...
# 1767                                               **  ...
# 1768                                              2.9  ...
# 1769                                             19.9  ...
# 1770                                              0.1  ...
#
#                                          S1901_C04_012E  \
# 0     Nonfamily households!!Estimate!!Median income ...
# 1                                                 28250
# 2                                                 21318
# 3                                                 24986
# 4                                                 41765
# ...                                                 ...
# 1766                                              30209
# 1767                                                  -
# 1768                                              50897
# 1769                                              26923
# 1770                                              40639
#
#                                          S1901_C04_012M  \
# 0     Nonfamily households!!Margin of Error!!Median ...
# 1                                                 16533
# 2                                                  5780
# 3                                                  5129
# 4                                                 18185
# ...                                                 ...
# 1766                                               2237
# 1767                                                 **
# 1768                                               7138
# 1769                                               5491
# 1770                                                170
#
#                                          S1901_C04_013E  \
# 0     Nonfamily households!!Estimate!!Mean income (d...
# 1                                                 30674
# 2                                                 29987
# 3                                                 41715
# 4                                                 57568
# ...                                                 ...
# 1766                                              42126
# 1767                                                  -
# 1768                                              82038
# 1769                                              24777
# 1770                                              60326
#
#                                          S1901_C04_013M  \
# 0     Nonfamily households!!Margin of Error!!Mean in...
# 1                                                 10680
# 2                                                  9446
# 3                                                 18821
# 4                                                 19172
# ...                                                 ...
# 1766                                               3498
# 1767                                                 **
# 1768                                              22815
# 1769                                               5116
# 1770                                                272
#
#                                          S1901_C04_014E  \
# 0     Nonfamily households!!Estimate!!PERCENT IMPUTE...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 1766                                                (X)
# 1767                                                (X)
# 1768                                                (X)
# 1769                                                (X)
# 1770                                                (X)
#
#                                          S1901_C04_014M  \
# 0     Nonfamily households!!Margin of Error!!PERCENT...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 1766                                                (X)
# 1767                                                (X)
# 1768                                                (X)
# 1769                                                (X)
# 1770                                                (X)
#
#                                          S1901_C04_015E  \
# 0     Nonfamily households!!Estimate!!PERCENT IMPUTE...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 1766                                                (X)
# 1767                                                (X)
# 1768                                                (X)
# 1769                                                (X)
# 1770                                                (X)
#
#                                          S1901_C04_015M  \
# 0     Nonfamily households!!Margin of Error!!PERCENT...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 1766                                                (X)
# 1767                                                (X)
# 1768                                                (X)
# 1769                                                (X)
# 1770                                                (X)
#
#                                          S1901_C04_016E  \
# 0     Nonfamily households!!Estimate!!PERCENT IMPUTE...
# 1                                                  27.9
# 2                                                  31.9
# 3                                                  28.9
# 4                                                  20.3
# ...                                                 ...
# 1766                                               26.8
# 1767                                                  -
# 1768                                               34.6
# 1769                                                0.0
# 1770                                               26.8
#
#                                          S1901_C04_016M
# 0     Nonfamily households!!Margin of Error!!PERCENT...
# 1                                                   (X)
# 2                                                   (X)
# 3                                                   (X)
# 4                                                   (X)
# ...                                                 ...
# 1766                                                (X)
# 1767                                                (X)
# 1768                                                (X)
# 1769                                                (X)
# 1770                                                (X)
#
# [1771 rows x 130 columns]

# %%
# cleaning data

# renaming columns
cali_14 = cali_14.rename(columns = cali_14.iloc[0]).iloc[1:]

# dropping final row
cali_14 = cali_14.iloc[:-1]

# filtering for id, median and mean income columns
cali_14 = cali_14[['id',
                   'Households!!Estimate!!Median income (dollars)',
                   'Households!!Estimate!!Mean income (dollars)']]

# rename columns
cali_14 = cali_14.rename(columns = {'id' : 'Zip',
                                    'Households!!Estimate!!Median income (dollars)' : 'median_income',
                                    'Households!!Estimate!!Mean income (dollars)' : 'mean_income'})

# dropping rows that contain non-numeric characters
cali_14 = cali_14[(pd.to_numeric(cali_14['mean_income'], errors = 'coerce').notnull()) & 
                  (pd.to_numeric(cali_14['median_income'], errors = 'coerce').notnull())]

# reseting index
cali_14.reset_index(inplace = True)

# extracting zip codes for zip id column
cali_14['Zip'] = cali_14.Zip.str[9:]

# casting all columns as integers
cali_14 = cali_14[['Zip', 'median_income', 'mean_income']].astype('int')

# snapshot
cali_14
# Out:
#         Zip  median_income  mean_income
# 0     89010          35000        45226
# 1     89019          37632        49179
# 2     89060          40726        52416
# 3     89061          55096        70373
# 4     89439          59275       122256
# ...     ...            ...          ...
# 1687  96146          53250        74270
# 1688  96148          52841        65040
# 1689  96150          47500        62684
# 1690  96161          75172       105535
# 1691  97635          31477        43666
#
# [1692 rows x 3 columns]

# %%
# output to csv
#cali_14.to_csv(r"../Data/US 2014 Census Data/California_2014_Zip_Income.csv",
#               index=False)

# %% [markdown]
# ---
#
# ## Joining tables
#
# We will be testing the following hypotheses.
#
# Is there a relationship between getting free or reduced lunch, the mean income of the Zip code of the school, and performance on the Math portion of the SAT.
#
# Specifically,
# - $y$ is Avg Math SAT Score
# - $x_1$ is percentage of students recieving free or reduce lunch at the school
# - $x_2$ is the mean income of the zip code of the school
#
#
# **Game Plan:**
# We have two options.
#
# - Let `schools` be the left table, and Left Join the three tables `frpm`, `sat_scores` and `cali_14` to `schools`.
# - Let `sat_scores` be the left table, and Left Join two tables, `frpm` and `schools`, then Inner Join the three tables to `cali_14`.
#
# Lads the three cells below are to test the difference in cardinality between two different approaches to joining the tables.

# %%
#test_1 = frpm[['Low Grade', 'High Grade']]

#test_1[(test_1['Low Grade'] == '9') & (test_1['High Grade'] == '12')]

#schools.merge(frpm, on = 'CDSCode', how = 'left')

# %%
#test_2 = schools.merge(frpm, on = 'CDSCode', how = 'left')

#test_2[(test_2['Low Grade'] == '9') & (test_2['High Grade'] == '12')]

# %%
#schools.merge(frpm, on = 'CDSCode', how = 'left')

# %%
################
# Attempt 1
# Let `schools` be the left table and left join everything to it
################

# schools_income_df
schools_income_df = schools.merge(cali_14, on = 'Zip', how = 'inner')

# schools_income_frpm_df
schools_income_frpm_df = schools_income_df.merge(frpm, on = 'CDSCode', how = 'left')

# schools_income_frpm_sat_scores_df
master_df = schools_income_frpm_df.merge(sat_scores, on = 'CDSCode', how = 'left')

# print cardinalities
print(len(schools))
print(len(schools_income_df))
print(len(schools_income_frpm_df))
print(len(master_df))

# snapshot
master_df
# Out:
# 5000
# 4844
# 4844
# 4844
#              CDSCode NCESDist NCESSchool StatusType       County Distrinct  \
# 0     01100170000000  0691051                Active      Alameda      None
# 1     01100170130419  0691051      06830     Active      Alameda      None
# 2     01100170130427  0691051      09265     Closed      Alameda      None
# 3     01100176106751  0691051      08672     Active      Alameda      None
# 4     01611920000000  0616740                Active      Alameda      None
# ...              ...      ...        ...        ...          ...       ...
# 4839  19647330117762  0622710      12370     Active  Los Angeles      None
# 4840  19647330119693  0622710      12524     Active  Los Angeles      None
# 4841  19647330119735  0622710      12440     Active  Los Angeles      None
# 4842  19647330117846  0622710      12361     Active  Los Angeles      None
# 4843  19647330117911  0622710      12253     Active  Los Angeles      None
#
#                                          School  \
# 0
# 1                      Alameda County Community
# 2                    Alameda County Opportunity
# 3              Alameda County Special Education
# 4
# ...                                         ...
# 4839  School for the Visual Arts and Humanities
# 4840                        UCLA Community K-12
# 4841                      Young Oak Kim Academy
# 4842                      Para Los Niños Middle
# 4843                   New Millennium Secondary
#
#                                    Street                     StreetAbr  \
# 0                  313 West Winton Avenue          313 West Winton Ave.
# 1                  313 West Winton Avenue          313 West Winton Ave.
# 2                  313 West Winton Avenue          313 West Winton Ave.
# 3                  313 West Winton Avenue          313 West Winton Ave.
# 4                     24411 Amador Street              24411 Amador St.
# ...                                   ...                           ...
# 4839            701 South Catalina Street        701 South Catalina St.
# 4840            700 South Mariposa Avenue       700 South Mariposa Ave.
# 4841               615 South Shatto Place          615 South Shatto Pl.
# 4842                  835 Stanford Avenue             835 Stanford Ave.
# 4843  1301 WeStreet 182nd Street, Suite B  1301 West. 182nd St., Ste. B
#
#              City  ...                                              sname  \
# 0         Hayward  ...                                                NaN
# 1         Hayward  ...                                                NaN
# 2         Hayward  ...                                                NaN
# 3         Hayward  ...                                                NaN
# 4         Hayward  ...                                                NaN
# ...           ...  ...                                                ...
# 4839  Los Angeles  ...  RFK Community Schools- for the Visual Arts and...
# 4840  Los Angeles  ...          RFK Community Schools-UCLA Community K-12
# 4841  Los Angeles  ...                                                NaN
# 4842  Los Angeles  ...                                                NaN
# 4843      Gardena  ...                           New Millennium Secondary
#
#                     dname        cname enroll12 NumTstTakr AvgScrRead  \
# 0                     NaN          NaN      NaN        NaN        NaN
# 1                     NaN          NaN      NaN        NaN        NaN
# 2                     NaN          NaN      NaN        NaN        NaN
# 3                     NaN          NaN      NaN        NaN        NaN
# 4                     NaN          NaN      NaN        NaN        NaN
# ...                   ...          ...      ...        ...        ...
# 4839  Los Angeles Unified  Los Angeles     81.0       71.0      392.0
# 4840  Los Angeles Unified  Los Angeles     75.0       61.0      384.0
# 4841                  NaN          NaN      NaN        NaN        NaN
# 4842                  NaN          NaN      NaN        NaN        NaN
# 4843  Los Angeles Unified  Los Angeles     67.0       44.0      387.0
#
#      AvgScrMath AvgScrWrite NumGE1500 PctGE1500
# 0           NaN         NaN       NaN       NaN
# 1           NaN         NaN       NaN       NaN
# 2           NaN         NaN       NaN       NaN
# 3           NaN         NaN       NaN       NaN
# 4           NaN         NaN       NaN       NaN
# ...         ...         ...       ...       ...
# 4839      416.0       394.0      12.0     16.90
# 4840      404.0       392.0       6.0      9.84
# 4841        NaN         NaN       NaN       NaN
# 4842        NaN         NaN       NaN       NaN
# 4843      378.0       388.0       3.0      6.82
#
# [4844 rows x 91 columns]

# %%
################
# Attempt 2
# Let `sat_scores` be the left table and left join everything to it
################

# sat_scores_frpm_df
sat_scores_frpm_df = sat_scores.merge(frpm, on = 'CDSCode', how = 'left')

# sat_scores_frpm_schools_df
sat_scores_frpm_schools_df = sat_scores_frpm_df.merge(schools, on = 'CDSCode', how = 'left')

# schools_income_frpm_sat_scores_df
master_df = sat_scores_frpm_schools_df.merge(cali_14, on = 'Zip', how = 'inner')

# print cardinalities
print(len(sat_scores))
print(len(sat_scores_frpm_df))
print(len(sat_scores_frpm_schools_df))
print(len(master_df))

# snapshot
master_df
# Out:
# 1753
# 1753
# 1753
# 487
#             CDSCode rtype                                              sname  \
# 0    01100170109835     S                                FAME Public Charter
# 1    01612340130054     S                               Newark Memorial High
# 2    01612340130484     S                      Crossroads High (Alternative)
# 3    01100170112607     S             Envision Academy for Arts & Technology
# 4    01612593030772     S                        Oakland School for the Arts
# ..              ...   ...                                                ...
# 482  19647330119693     S          RFK Community Schools-UCLA Community K-12
# 483  19647330117911     S                           New Millennium Secondary
# 484  19647330119685     S  RFK Community Schools-New Open World Academy K-12
# 485  19647330119727     S  Ramon C. Cortines School of Visual and Performing
# 486  19647330119966     S                  Felicitas and Gonzalo Mendez High
#
#                                   dname        cname  enroll12  NumTstTakr  \
# 0    Alameda County Office of Education      Alameda        62          17
# 1                        Newark Unified      Alameda       444         234
# 2                        Newark Unified      Alameda        15           0
# 3    Alameda County Office of Education      Alameda        75          71
# 4                       Oakland Unified      Alameda        99          80
# ..                                  ...          ...       ...         ...
# 482                 Los Angeles Unified  Los Angeles        75          61
# 483                 Los Angeles Unified  Los Angeles        67          44
# 484                 Los Angeles Unified  Los Angeles        45          33
# 485                 Los Angeles Unified  Los Angeles       356         249
# 486                 Los Angeles Unified  Los Angeles       142          58
#
#      AvgScrRead  AvgScrMath  AvgScrWrite  ...  AdmFName2  AdmLName2 AdmEmail2  \
# 0         503.0       546.0        505.0  ...
# 1         486.0       498.0        487.0  ...
# 2           NaN         NaN          NaN  ...
# 3         397.0       387.0        395.0  ...
# 4         529.0       470.0        523.0  ...
# ..          ...         ...          ...  ...        ...        ...       ...
# 482       384.0       404.0        392.0  ...
# 483       387.0       378.0        388.0  ...
# 484       402.0       387.0        402.0  ...
# 485       451.0       434.0        446.0  ...
# 486       390.0       396.0        382.0  ...
#
#     AdmFName3  AdmLName3 AdmEmail3  LastUpdate  \
# 0                                   2015-09-01
# 1                                   2015-10-06
# 2                                   2015-10-06
# 3                                   2015-06-18
# 4                                   2016-04-19
# ..        ...        ...       ...         ...
# 482                                 2016-10-05
# 483                                 2016-09-29
# 484                                 2016-10-05
# 485                                 2016-03-03
# 486                                 2016-03-03
#
#                                district median_income mean_income
# 0    Alameda County Office of Education         86521       98373
# 1                        Newark Unified         86521       98373
# 2                        Newark Unified         86521       98373
# 3    Alameda County Office of Education         30879       50381
# 4                       Oakland Unified         30879       50381
# ..                                  ...           ...         ...
# 482                 Los Angeles Unified         31214       45746
# 483                 Los Angeles Unified         51956       67133
# 484                 Los Angeles Unified         47308       71900
# 485                 Los Angeles Unified         29492       50578
# 486                 Los Angeles Unified         27190       38191
#
# [487 rows x 91 columns]

# %%
# master_df column names
master_df.columns
# Out:
# Index(['CDSCode', 'rtype', 'sname', 'dname', 'cname', 'enroll12', 'NumTstTakr',
#        'AvgScrRead', 'AvgScrMath', 'AvgScrWrite', 'NumGE1500', 'PctGE1500',
#        'Academic Year', 'County Code', 'District Code', 'School Code',
#        'County Name', 'District Name', 'School Name', 'District Type',
#        'School Type', 'Educational Option Type', 'NSLP Provision Status',
#        'Charter School (Y/N)', 'Charter School Number', 'Charter Funding Type',
#        'IRC', 'Low Grade', 'High Grade', 'Enrollment (K-12)',
#        'Free Meal Count (K-12)', 'Percent (%) Eligible Free (K-12)',
#        'FRPM Count (K-12)', 'Percent (%) Eligible FRPM (K-12)',
#        'Enrollment (Ages 5-17)', 'Free Meal Count (Ages 5-17)',
#        'Percent (%) Eligible Free (Ages 5-17)', 'FRPM Count (Ages 5-17)',
#        'Percent (%) Eligible FRPM (Ages 5-17)',
#        '2013-14 CALPADS Fall 1 Certification Status', 'NCESDist', 'NCESSchool',
#        'StatusType', 'County', 'Distrinct', 'School', 'Street', 'StreetAbr',
#        'City', 'Zip', 'State', 'MailStreet', 'MailStrAbr', 'MailCity',
#        'MailZip', 'MailState', 'Phone', 'Ext', 'Website', 'OpenDate',
#        'ClosedDate', 'Charter', 'CharterNum', 'FundingType', 'DOC', 'DOCType',
#        'SOC', 'SOCType', 'EdOpsCode', 'EdOpsName', 'EILCode', 'EILName',
#        'GSoffered', 'GSserved', 'Virtual', 'Magnet', 'Latitude', 'Longitude',
#        'AdmFName1', 'AdmLName1', 'AdmEmail1', 'AdmFName2', 'AdmLName2',
#        'AdmEmail2', 'AdmFName3', 'AdmLName3', 'AdmEmail3', 'LastUpdate',
#        'district', 'median_income', 'mean_income'],
#       dtype='object')

# %%
# filtering for relevant columns
clean_master_df = master_df[["CDSCode",
                            # cali income data
                            'Zip',
                            'median_income',
                            'mean_income',
                            # frpm
                            "County",
                            "Distrinct",
                            "School Name",
                            "District Type",
                            "School Type",
                            "Low Grade",
                            "High Grade",
                            "Enrollment (K-12)",
                            "Enrollment (K-12)", 
                            "Free Meal Count (K-12)", 
                            "Percent (%) Eligible Free (K-12)", 
                            "FRPM Count (K-12)", 
                            "Percent (%) Eligible FRPM (K-12)", 
                            # sat scores
                            "AvgScrRead", 
                            "AvgScrMath",
                            "AvgScrWrite", 
                              ]]

#snapshot
clean_master_df
# Out:
#             CDSCode      Zip  median_income  mean_income       County  \
# 0    01100170109835  94560.0          86521        98373      Alameda
# 1    01612340130054  94560.0          86521        98373      Alameda
# 2    01612340130484  94560.0          86521        98373      Alameda
# 3    01100170112607  94612.0          30879        50381      Alameda
# 4    01612593030772  94612.0          30879        50381      Alameda
# ..              ...      ...            ...          ...          ...
# 482  19647330119693  90005.0          31214        45746  Los Angeles
# 483  19647330117911  90248.0          51956        67133  Los Angeles
# 484  19647330119685  90010.0          47308        71900  Los Angeles
# 485  19647330119727  90012.0          29492        50578  Los Angeles
# 486  19647330119966  90033.0          27190        38191  Los Angeles
#
#     Distrinct                                        School Name  \
# 0        None                                                NaN
# 1        None                               Newark Memorial High
# 2        None                                                NaN
# 3        None             Envision Academy for Arts & Technology
# 4        None                                                NaN
# ..        ...                                                ...
# 482      None                                                NaN
# 483      None                           New Millennium Secondary
# 484      None                                                NaN
# 485      None  Ramon C. Cortines School of Visual and Perform...
# 486      None                  Felicitas and Gonzalo Mendez High
#
#                         District Type            School Type Low Grade  \
# 0                                 NaN                    NaN       NaN
# 1             Unified School District  High Schools (Public)         9
# 2                                 NaN                    NaN       NaN
# 3    County Office of Education (COE)  High Schools (Public)         9
# 4                                 NaN                    NaN       NaN
# ..                                ...                    ...       ...
# 482                               NaN                    NaN       NaN
# 483           Unified School District  High Schools (Public)         9
# 484                               NaN                    NaN       NaN
# 485           Unified School District  High Schools (Public)         9
# 486           Unified School District  High Schools (Public)         9
#
#     High Grade  Enrollment (K-12)  Enrollment (K-12)  Free Meal Count (K-12)  \
# 0          NaN                NaN                NaN                     NaN
# 1           12             1850.0             1850.0                   703.0
# 2          NaN                NaN                NaN                     NaN
# 3           12              395.0              395.0                   186.0
# 4          NaN                NaN                NaN                     NaN
# ..         ...                ...                ...                     ...
# 482        NaN                NaN                NaN                     NaN
# 483         12              196.0              196.0                   119.0
# 484        NaN                NaN                NaN                     NaN
# 485         12             1647.0             1647.0                   892.0
# 486         12              792.0              792.0                   675.0
#
#      Percent (%) Eligible Free (K-12)  FRPM Count (K-12)  \
# 0                                 NaN                NaN
# 1                            0.380000              838.0
# 2                                 NaN                NaN
# 3                            0.470886              186.0
# 4                                 NaN                NaN
# ..                                ...                ...
# 482                               NaN                NaN
# 483                          0.607143              142.0
# 484                               NaN                NaN
# 485                          0.541591             1015.0
# 486                          0.852273              685.0
#
#      Percent (%) Eligible FRPM (K-12)  AvgScrRead  AvgScrMath  AvgScrWrite
# 0                                 NaN       503.0       546.0        505.0
# 1                            0.452973       486.0       498.0        487.0
# 2                                 NaN         NaN         NaN          NaN
# 3                            0.470886       397.0       387.0        395.0
# 4                                 NaN       529.0       470.0        523.0
# ..                                ...         ...         ...          ...
# 482                               NaN       384.0       404.0        392.0
# 483                          0.724490       387.0       378.0        388.0
# 484                               NaN       402.0       387.0        402.0
# 485                          0.616272       451.0       434.0        446.0
# 486                          0.864899       390.0       396.0        382.0
#
# [487 rows x 20 columns]

# %% [markdown]
# ## Preparing for Hypothesis Test - `AvgScrMath`
#
# We wish to see how the average Math SAT score at a school is a function of mean income and FRPM.
#
# I propose to consider the proportions of the students at a school recieving free lunch, and reduced lunch, and financial assistance instead of the counts of students. Consider if a big school has a high proportion of students recieving any financial lunch aid, and if a small school has a low number of student recieving aid. The count of students are disproportionate. To this end, we'll create three new columns.
#
# Also, we can remove any rows where `AvgScrMath` is false. We'll initialize a new data frame in case we want to repeat this procedure with SAT reading or writing scores.

# %%
# Initializing new df
math_df = clean_master_df.copy()

# dropping duplicate columns (idk why but this works)
math_df = math_df.T.drop_duplicates().T

# snapshot
math_df
# Out:
#             CDSCode      Zip median_income mean_income       County Distrinct  \
# 0    01100170109835  94560.0         86521       98373      Alameda      None
# 1    01612340130054  94560.0         86521       98373      Alameda      None
# 2    01612340130484  94560.0         86521       98373      Alameda      None
# 3    01100170112607  94612.0         30879       50381      Alameda      None
# 4    01612593030772  94612.0         30879       50381      Alameda      None
# ..              ...      ...           ...         ...          ...       ...
# 482  19647330119693  90005.0         31214       45746  Los Angeles      None
# 483  19647330117911  90248.0         51956       67133  Los Angeles      None
# 484  19647330119685  90010.0         47308       71900  Los Angeles      None
# 485  19647330119727  90012.0         29492       50578  Los Angeles      None
# 486  19647330119966  90033.0         27190       38191  Los Angeles      None
#
#                                            School Name  \
# 0                                                  NaN
# 1                                 Newark Memorial High
# 2                                                  NaN
# 3               Envision Academy for Arts & Technology
# 4                                                  NaN
# ..                                                 ...
# 482                                                NaN
# 483                           New Millennium Secondary
# 484                                                NaN
# 485  Ramon C. Cortines School of Visual and Perform...
# 486                  Felicitas and Gonzalo Mendez High
#
#                         District Type            School Type Low Grade  \
# 0                                 NaN                    NaN       NaN
# 1             Unified School District  High Schools (Public)         9
# 2                                 NaN                    NaN       NaN
# 3    County Office of Education (COE)  High Schools (Public)         9
# 4                                 NaN                    NaN       NaN
# ..                                ...                    ...       ...
# 482                               NaN                    NaN       NaN
# 483           Unified School District  High Schools (Public)         9
# 484                               NaN                    NaN       NaN
# 485           Unified School District  High Schools (Public)         9
# 486           Unified School District  High Schools (Public)         9
#
#     High Grade Enrollment (K-12) Free Meal Count (K-12)  \
# 0          NaN               NaN                    NaN
# 1           12            1850.0                  703.0
# 2          NaN               NaN                    NaN
# 3           12             395.0                  186.0
# 4          NaN               NaN                    NaN
# ..         ...               ...                    ...
# 482        NaN               NaN                    NaN
# 483         12             196.0                  119.0
# 484        NaN               NaN                    NaN
# 485         12            1647.0                  892.0
# 486         12             792.0                  675.0
#
#     Percent (%) Eligible Free (K-12) FRPM Count (K-12)  \
# 0                                NaN               NaN
# 1                               0.38             838.0
# 2                                NaN               NaN
# 3                           0.470886             186.0
# 4                                NaN               NaN
# ..                               ...               ...
# 482                              NaN               NaN
# 483                         0.607143             142.0
# 484                              NaN               NaN
# 485                         0.541591            1015.0
# 486                         0.852273             685.0
#
#     Percent (%) Eligible FRPM (K-12) AvgScrRead AvgScrMath AvgScrWrite
# 0                                NaN      503.0      546.0       505.0
# 1                           0.452973      486.0      498.0       487.0
# 2                                NaN        NaN        NaN         NaN
# 3                           0.470886      397.0      387.0       395.0
# 4                                NaN      529.0      470.0       523.0
# ..                               ...        ...        ...         ...
# 482                              NaN      384.0      404.0       392.0
# 483                          0.72449      387.0      378.0       388.0
# 484                              NaN      402.0      387.0       402.0
# 485                         0.616272      451.0      434.0       446.0
# 486                         0.864899      390.0      396.0       382.0
#
# [487 rows x 19 columns]

# %%
# drop rows where `AvgScrMath` is NaN
math_df.dropna(subset = ['AvgScrMath'])

# reset index
# Out:
#             CDSCode      Zip median_income mean_income       County Distrinct  \
# 0    01100170109835  94560.0         86521       98373      Alameda      None
# 1    01612340130054  94560.0         86521       98373      Alameda      None
# 3    01100170112607  94612.0         30879       50381      Alameda      None
# 4    01612593030772  94612.0         30879       50381      Alameda      None
# 6    01611190106401  94501.0         70935       94830      Alameda      None
# ..              ...      ...           ...         ...          ...       ...
# 482  19647330119693  90005.0         31214       45746  Los Angeles      None
# 483  19647330117911  90248.0         51956       67133  Los Angeles      None
# 484  19647330119685  90010.0         47308       71900  Los Angeles      None
# 485  19647330119727  90012.0         29492       50578  Los Angeles      None
# 486  19647330119966  90033.0         27190       38191  Los Angeles      None
#
#                                            School Name  \
# 0                                                  NaN
# 1                                 Newark Memorial High
# 3               Envision Academy for Arts & Technology
# 4                                                  NaN
# 6             Alameda Science and Technology Institute
# ..                                                 ...
# 482                                                NaN
# 483                           New Millennium Secondary
# 484                                                NaN
# 485  Ramon C. Cortines School of Visual and Perform...
# 486                  Felicitas and Gonzalo Mendez High
#
#                         District Type                    School Type  \
# 0                                 NaN                            NaN
# 1             Unified School District          High Schools (Public)
# 3    County Office of Education (COE)          High Schools (Public)
# 4                                 NaN                            NaN
# 6             Unified School District  Alternative Schools of Choice
# ..                                ...                            ...
# 482                               NaN                            NaN
# 483           Unified School District          High Schools (Public)
# 484                               NaN                            NaN
# 485           Unified School District          High Schools (Public)
# 486           Unified School District          High Schools (Public)
#
#     Low Grade High Grade Enrollment (K-12) Free Meal Count (K-12)  \
# 0         NaN        NaN               NaN                    NaN
# 1           9         12            1850.0                  703.0
# 3           9         12             395.0                  186.0
# 4         NaN        NaN               NaN                    NaN
# 6           9         12             170.0                   39.0
# ..        ...        ...               ...                    ...
# 482       NaN        NaN               NaN                    NaN
# 483         9         12             196.0                  119.0
# 484       NaN        NaN               NaN                    NaN
# 485         9         12            1647.0                  892.0
# 486         9         12             792.0                  675.0
#
#     Percent (%) Eligible Free (K-12) FRPM Count (K-12)  \
# 0                                NaN               NaN
# 1                               0.38             838.0
# 3                           0.470886             186.0
# 4                                NaN               NaN
# 6                           0.229412              52.0
# ..                               ...               ...
# 482                              NaN               NaN
# 483                         0.607143             142.0
# 484                              NaN               NaN
# 485                         0.541591            1015.0
# 486                         0.852273             685.0
#
#     Percent (%) Eligible FRPM (K-12) AvgScrRead AvgScrMath AvgScrWrite
# 0                                NaN      503.0      546.0       505.0
# 1                           0.452973      486.0      498.0       487.0
# 3                           0.470886      397.0      387.0       395.0
# 4                                NaN      529.0      470.0       523.0
# 6                           0.305882      562.0      590.0       555.0
# ..                               ...        ...        ...         ...
# 482                              NaN      384.0      404.0       392.0
# 483                          0.72449      387.0      378.0       388.0
# 484                              NaN      402.0      387.0       402.0
# 485                         0.616272      451.0      434.0       446.0
# 486                         0.864899      390.0      396.0       382.0
#
# [359 rows x 19 columns]

# %%
# Creating new columns
math_df['free_lunch'] = 

math_df['reduced_lunch'] = 

math_df['full_lunch'] =

# %%
1 - math_df['Percent (%) Eligible FRPM (K-12)']
# Out:
# 0           NaN
# 1      0.547027
# 2           NaN
# 3      0.529114
# 4           NaN
#          ...
# 482         NaN
# 483     0.27551
# 484         NaN
# 485    0.383728
# 486    0.135101
# Name: Percent (%) Eligible FRPM (K-12), Length: 487, dtype: object

# %%
math_df
# Out:
#             CDSCode      Zip median_income mean_income       County Distrinct  \
# 0    01100170109835  94560.0         86521       98373      Alameda      None
# 1    01612340130054  94560.0         86521       98373      Alameda      None
# 2    01612340130484  94560.0         86521       98373      Alameda      None
# 3    01100170112607  94612.0         30879       50381      Alameda      None
# 4    01612593030772  94612.0         30879       50381      Alameda      None
# ..              ...      ...           ...         ...          ...       ...
# 482  19647330119693  90005.0         31214       45746  Los Angeles      None
# 483  19647330117911  90248.0         51956       67133  Los Angeles      None
# 484  19647330119685  90010.0         47308       71900  Los Angeles      None
# 485  19647330119727  90012.0         29492       50578  Los Angeles      None
# 486  19647330119966  90033.0         27190       38191  Los Angeles      None
#
#                                            School Name  \
# 0                                                  NaN
# 1                                 Newark Memorial High
# 2                                                  NaN
# 3               Envision Academy for Arts & Technology
# 4                                                  NaN
# ..                                                 ...
# 482                                                NaN
# 483                           New Millennium Secondary
# 484                                                NaN
# 485  Ramon C. Cortines School of Visual and Perform...
# 486                  Felicitas and Gonzalo Mendez High
#
#                         District Type            School Type Low Grade  ...  \
# 0                                 NaN                    NaN       NaN  ...
# 1             Unified School District  High Schools (Public)         9  ...
# 2                                 NaN                    NaN       NaN  ...
# 3    County Office of Education (COE)  High Schools (Public)         9  ...
# 4                                 NaN                    NaN       NaN  ...
# ..                                ...                    ...       ...  ...
# 482                               NaN                    NaN       NaN  ...
# 483           Unified School District  High Schools (Public)         9  ...
# 484                               NaN                    NaN       NaN  ...
# 485           Unified School District  High Schools (Public)         9  ...
# 486           Unified School District  High Schools (Public)         9  ...
#
#     Free Meal Count (K-12) Percent (%) Eligible Free (K-12) FRPM Count (K-12)  \
# 0                      NaN                              NaN               NaN
# 1                    703.0                             0.38             838.0
# 2                      NaN                              NaN               NaN
# 3                    186.0                         0.470886             186.0
# 4                      NaN                              NaN               NaN
# ..                     ...                              ...               ...
# 482                    NaN                              NaN               NaN
# 483                  119.0                         0.607143             142.0
# 484                    NaN                              NaN               NaN
# 485                  892.0                         0.541591            1015.0
# 486                  675.0                         0.852273             685.0
#
#     Percent (%) Eligible FRPM (K-12) NumTstTakr AvgScrRead AvgScrMath  \
# 0                                NaN         17      503.0      546.0
# 1                           0.452973        234      486.0      498.0
# 2                                NaN          0        NaN        NaN
# 3                           0.470886         71      397.0      387.0
# 4                                NaN         80      529.0      470.0
# ..                               ...        ...        ...        ...
# 482                              NaN         61      384.0      404.0
# 483                          0.72449         44      387.0      378.0
# 484                              NaN         33      402.0      387.0
# 485                         0.616272        249      451.0      434.0
# 486                         0.864899         58      390.0      396.0
#
#     AvgScrWrite NumGE1500 PctGE1500
# 0         505.0       9.0     52.94
# 1         487.0     105.0     44.87
# 2           NaN       NaN       NaN
# 3         395.0       5.0      7.04
# 4         523.0      40.0      50.0
# ..          ...       ...       ...
# 482       392.0       6.0      9.84
# 483       388.0       3.0      6.82
# 484       402.0       2.0      6.06
# 485       446.0      73.0     29.32
# 486       382.0       6.0     10.34
#
# [487 rows x 22 columns]

# %%
math_df
# Out:
# Index(['CDSCode', 'Zip', 'median_income', 'mean_income', 'County', 'Distrinct',
#        'School Name', 'District Type', 'School Type', 'Low Grade',
#        'High Grade', 'Enrollment (K-12)', 'Free Meal Count (K-12)',
#        'Percent (%) Eligible Free (K-12)', 'FRPM Count (K-12)',
#        'Percent (%) Eligible FRPM (K-12)', 'NumTstTakr', 'AvgScrRead',
#        'AvgScrMath', 'AvgScrWrite', 'NumGE1500', 'PctGE1500'],
#       dtype='object')

# %% [markdown]
# ## Hypothesis Testing #1
